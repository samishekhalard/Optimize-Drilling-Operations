# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingRegressor

# %%
df.head()
# Out:
#     Depth        WOB  SURF_RPM   ROP_AVG      PHIF       VSH   SW  KLOGH
# 0  3305.0  26217.864  1.314720  0.004088  0.086711  0.071719  1.0  0.001
# 1  3310.0  83492.293  1.328674  0.005159  0.095208  0.116548  1.0  0.001
# 2  3315.0  97087.882  1.420116  0.005971  0.061636  0.104283  1.0  0.001
# 3  3320.0  54793.206  1.593931  0.005419  0.043498  0.110040  1.0  0.001
# 4  3325.0  50301.579  1.653262  0.005435  0.035252  0.120808  1.0  0.001

# %%
# @title ROP_AVG

from matplotlib import pyplot as plt
df['ROP_AVG'].plot(kind='line', figsize=(8, 4), title='ROP_AVG')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title SURF_RPM

from matplotlib import pyplot as plt
df['SURF_RPM'].plot(kind='line', figsize=(8, 4), title='SURF_RPM')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title WOB

from matplotlib import pyplot as plt
df['WOB'].plot(kind='line', figsize=(8, 4), title='WOB')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Depth

from matplotlib import pyplot as plt
df['Depth'].plot(kind='line', figsize=(8, 4), title='Depth')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Depth vs PHIF

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Depth']
  ys = series['PHIF']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Depth', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Depth')
_ = plt.ylabel('PHIF')

# %%
# @title Depth vs ROP_AVG

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Depth']
  ys = series['ROP_AVG']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Depth', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Depth')
_ = plt.ylabel('ROP_AVG')

# %%
# @title Depth vs SURF_RPM

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Depth']
  ys = series['SURF_RPM']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Depth', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Depth')
_ = plt.ylabel('SURF_RPM')

# %%
# @title Depth vs WOB

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Depth']
  ys = series['WOB']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Depth', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Depth')
_ = plt.ylabel('WOB')

# %%
# @title Depth vs WOB

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Depth', y='WOB', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title ROP_AVG vs PHIF

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='ROP_AVG', y='PHIF', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title SURF_RPM vs ROP_AVG

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='SURF_RPM', y='ROP_AVG', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title WOB vs SURF_RPM

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='WOB', y='SURF_RPM', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title ROP_AVG

from matplotlib import pyplot as plt
df['ROP_AVG'].plot(kind='hist', bins=20, title='ROP_AVG')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title SURF_RPM

from matplotlib import pyplot as plt
df['SURF_RPM'].plot(kind='hist', bins=20, title='SURF_RPM')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title WOB

from matplotlib import pyplot as plt
df['WOB'].plot(kind='hist', bins=20, title='WOB')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Depth

from matplotlib import pyplot as plt
df['Depth'].plot(kind='hist', bins=20, title='Depth')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df = pd.read_csv('/content/sample_data/ROP data .csv')
logs = df.columns[1:]
colors = ['red', 'orange', 'green', 'cyan', 'blue', 'violet', 'purple']

plt.figure(figsize=(30, 10))
for i in range(len(logs)):
    plt.subplot(1, 8, i + 1)
    plt.plot(df[logs[i]], df.Depth, color=colors[i])
    plt.title(logs[i])
    plt.gca().invert_yaxis()
    plt.tight_layout()

# %%
df.describe()
# Out:
#              Depth           WOB    SURF_RPM     ROP_AVG        PHIF  \
# count   151.000000    151.000000  151.000000  151.000000  151.000000
# mean   3697.417219  45393.934391    2.034981    0.007800    0.084423
# std     227.169433  15784.246882    0.208492    0.001476    0.068230
# min    3305.000000  16961.916000    1.314720    0.002666    0.002968
# 25%    3502.500000  34320.946500    1.998711    0.007368    0.037550
# 50%    3700.000000  44243.480000    1.999697    0.008157    0.059274
# 75%    3887.500000  53212.685000    2.001069    0.008760    0.097212
# max    4085.000000  97087.882000    2.639233    0.010447    0.279346
#
#               VSH          SW       KLOGH
# count  151.000000  151.000000  151.000000
# mean     0.299809    0.975579   37.072228
# std      0.264596    0.108946  127.186210
# min      0.049451    0.351393   -0.001124
# 25%      0.108539    1.000000    0.001000
# 50%      0.193100    1.000000    0.001000
# 75%      0.387664    1.000000    0.001000
# ...

# %%
df.corr()
# Out:
#              Depth       WOB  SURF_RPM   ROP_AVG      PHIF       VSH  \
# Depth     1.000000  0.159770 -0.104547  0.499131  0.521520  0.508014
# WOB       0.159770  1.000000  0.007013  0.027432  0.033606  0.045963
# SURF_RPM -0.104547  0.007013  1.000000  0.073833 -0.230075 -0.063986
# ROP_AVG   0.499131  0.027432  0.073833  1.000000  0.093381  0.349009
# PHIF      0.521520  0.033606 -0.230075  0.093381  1.000000  0.208022
# VSH       0.508014  0.045963 -0.063986  0.349009  0.208022  1.000000
# SW       -0.154379 -0.064150  0.043447 -0.080949 -0.501702 -0.580621
# KLOGH     0.402978  0.070220 -0.058486  0.149617  0.561610 -0.194376
#
#                 SW     KLOGH
# Depth    -0.154379  0.402978
# WOB      -0.064150  0.070220
# SURF_RPM  0.043447 -0.058486
# ROP_AVG  -0.080949  0.149617
# PHIF     -0.501702  0.561610
# VSH      -0.580621 -0.194376
# SW        1.000000  0.060306
# KLOGH     0.060306  1.000000

# %%
columns = ['Depth', 'WOB', 'SURF_RPM', 'ROP_AVG', 'PHIF', 'VSH', 'SW', 'KLOGH']
df = df[columns]
# Plotting the well log
fig, ax = plt.subplots(figsize=(10, 12))

ax.plot(df['PHIF'], df['Depth'], label='PHIF', color='blue')
ax.plot(df['VSH'], df['Depth'], label='VSH', color='green')
ax.plot(df['SW'], df['Depth'], label='SW', color='red')
ax.plot(df['KLOGH'], df['Depth'], label='KLOGH', color='orange')

ax.set_xlim(0, 1)
ax.set_ylim(df['Depth'].max(), df['Depth'].min())  # Reverse y-axis for depth

ax.set_xlabel('Porosity, Volume of Shale, Water Saturation, KLOGH')
ax.set_ylabel('Depth')
ax.set_title('Well Log')

ax.legend()
plt.grid(True)
plt.show()

# %%
columns = ['Depth', 'WOB', 'SURF_RPM', 'ROP_AVG', 'PHIF', 'VSH', 'SW', 'KLOGH']
# Create a correlation matrix
corr_matrix = df[columns].corr()

# Create a heatmap
plt.figure(figsize=(13, 9))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap of ROP Data')
plt.tight_layout()
# Display the plot
plt.show()

# %%
sns.pairplot(df[['WOB', 'ROP_AVG', 'SURF_RPM', 'PHIF', 'VSH']], corner=True)

# %%
plt.figure(figsize=(12, 8))
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df)
plt.title('Boxplot of Data')
plt.xlabel('Variables')
plt.ylabel('Values')
plt.show()

# %%
# Separate feature and target
X = df.drop(['ROP_AVG'], axis=1)
y = df['ROP_AVG']

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=10)

# Make pipeline
steps = [('scaler', StandardScaler()),
         ('gbr', GradientBoostingRegressor(min_samples_leaf=6, max_depth=20,
                                           random_state=10))]
pipe = Pipeline(steps)

# Fit pipeline to training data
pipe.fit(X_train, y_train)

# Evaluate model with R2 metric
train_score = pipe.score(X_train, y_train)
test_score = pipe.score(X_test, y_test)
print(f'R2 on train set: {train_score:.2f}')
print(f'R2 on test set: {test_score:.2f}')
# Out:
# R2 on train set: 0.98
# R2 on test set: 0.77

# %%
def predict(model, Depth, PHIF, VSH, SW, KLOGH, WOB, SURF_RPM):
    # Make a test input
    X_test = np.array([Depth, WOB, SURF_RPM, PHIF, VSH, SW, KLOGH])
    X_test = X_test.reshape(1, -1)

    # Predict on a test input
    y_pred = model.predict(X_test)
    return y_pred[0]


# Predict on new inputs
predict(pipe, 4000, 0.2, 0.5, 1, 500, WOB=5e4, SURF_RPM=2)
# Out:
# 0.008385100886684727

# %%
plt.rcParams['font.size'] = 20
def plot_space(model, WOB, SURF_RPM, constant_inputs):
    N_matrix = np.empty((len(WOB), len(SURF_RPM)))
    for i in range(len(WOB)):
        for j in range(len(SURF_RPM)):
            # Unwrap constant variables
            Depth, PHIF, VSH, SW, KLOGH = constant_inputs.values()
            N = predict(model, Depth, PHIF, VSH, SW, KLOGH, WOB=WOB[i], SURF_RPM=SURF_RPM[j])
            N_matrix[i][j] = N

    plt.imshow(N_matrix, origin='lower', aspect='auto', cmap='inferno',
               extent=(min(SURF_RPM), max(SURF_RPM), min(WOB), max(WOB)))
    plt.xlabel('SURF_RPM')
    plt.ylabel('WOB')
    plt.title('ROP_AVG', pad=10)
    plt.colorbar()
  # Range of WOB and RPM values
WOB = np.linspace(17e3, 90e3, 30)
SURF_RPM = np.linspace(1.5, 2.5, 30)

# Constant input variables
constant_inputs = {'Depth': 3480, 'PHIF': 0.09, 'VSH': 0.1,
                   'SW': 1, 'KLOGH': 0.001}

# Plot prediction space
plot_space(pipe, WOB, SURF_RPM, constant_inputs)

# %%
# !pip install pyswarm
import pyswarm as pso

# %%
# Define objective function. "pipe" as model
def f(X):
    return -pipe.predict(X.reshape(1, -1))  # Minus sign to optimize


# Lower bounds of feature variables in the order of X.columns
lb = [3480, 2e4, 1.5, 0.09, 0.1, 1, 0.001]

# Upper bounds of feature variables in the order of X.columns
ub = [3480, 9e4, 2.5, 0.09, 0.1, 1, 0.001]
ub = [u + 1e-10 for u in ub]

# Solve optimization
xopt, fopt = pso.pso(f, lb, ub, swarmsize=200, omega=0.3, phip=0.5,
                     phig=0.7, maxiter=1000, minstep=1e-8)
# Print values that cause maximum ROP from xopt
for i in range(len(X.columns)):
    print(f'{X.columns[i]}: {xopt[i]:.2f}')

# Print value of maximum ROP from fopt
print(f'Maximum ROP achieved: {-fopt}')
# Out:
# Stopping search: maximum iterations reached --> 1000
# Depth: 3480.00
# WOB: 87415.76
# SURF_RPM: 2.00
# PHIF: 0.09
# VSH: 0.10
# SW: 1.00
# KLOGH: 0.00
# Maximum ROP achieved: 0.00567214242229635
